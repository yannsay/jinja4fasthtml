# %% [markdown]
# ## fastjinja:
#
# I wanted to use Jinja templates with FastHTML to separate front-end and back-end concerns, but this wasn't directly supported. So I created `fastjinja` to bridge that gap.
#
# Maybe I am too used on the old way of programing but I find very confusing to have the back-end and front-end developped at the same place. In the example of lesson 4-5, we can see the fast iteration within the notebook to develop the web-app and it is amazing. But mixing the front-end and back-end logic is for me complicated as I don't see the separation of concerned.
#
# Also, I pondered a bit on the phrase from Jeremy "getting better a software development is creating layers of abstractions that makes your craft easier and not more complicated" (I hope I got that one right). We are front-row spetactors of seeing fastdaiy being created and the steps to make it happen. But I found it very "when you have a hammer, everything looks like a nail", and where python is the hammer and everything needs to be pythonic. convert html code to fasthml, convert tailwind/daisy to fasthtml components.
#
# I am familiar with Jinja template for front end, and for the moment I think I prefer that way of working. I can keep the separation of concern between front-end and back-end. I can have someone contributing on the html templates and not having to be a Python user (maybe that person should learn Python anyway).
#
# I have explored how I could get Jinja templates how to fit into the literrate programing, fasthml way of SolveIt, the same way daisy is being explored. I present you `fastjinja`.
#
# *When skiming throught hypermedia.systems, I was also very glad to see they are using jinja! Maybe next step will be re-writing hypermedia system with fasthtml and jinja.*

# %%
#| default_exp core

# %% [markdown]
# ## Writing Jinja from notebook

# %%
#| export
import jinja2 as jinja2
from fasthtml.common import *
from fasthtml.jupyter import *

# %% [markdown]
# Template from jinja2 conflict with another Template. That's why I import jinja2 as jinja2

# %%
app = FastHTML()
rt = app.route

# %%
jinja_template = """<div> {{ name }} </div>
"""
jinja_template
# Out:
# '<div> {{ name }} </div>\n'

# %%
template = jinja2.Template(jinja_template)
template
# Out:
# <Template memory:7d7731239c70>

# %%
template.render(name="Yann")
# Out:
# '<div> Yann </div>'

# %%
@rt
def jinja_ex(name):
    return template.render(name=name)

jinja_ex(name="Yann")
# Out:
# '<div> Yann </div>'

# %%
jinja_template2 = """<ul>
  {% for user in users %}
    <li><a href="{{ user.url }}">{{ user.username }}</a></li>
  {% endfor %}
  </ul>
"""
jinja_template2
# Out:
# '<ul>\n  {% for user in users %}\n    <li><a href="{{ user.url }}">{{ user.username }}</a></li>\n  {% endfor %}\n  </ul>\n'

# %%
template2 = jinja2.Template(jinja_template2)
template2
# Out:
# <Template memory:7d7732dd6240>

# %%
users_ex = [{"username":"Yann", "url":"yann@yann.yann"}, {"username":"Pierre", "url":"pierre@pierre.pierre"}]
users_ex
# Out:
# [{'username': 'Yann', 'url': 'yann@yann.yann'},
#  {'username': 'Pierre', 'url': 'pierre@pierre.pierre'}]

# %%
@rt
def jinja_ex2(users):
    return template2.render(users=users)

jinja_ex2(users=users_ex)
# Out:
# '<ul>\n  \n    <li><a href="yann@yann.yann">Yann</a></li>\n  \n    <li><a href="pierre@pierre.pierre">Pierre</a></li>\n  \n  </ul>'

# %% [markdown]
# ### Converting Jinja to FastHTML

# %%
def get_preview(app):
    return partial(HTMX, app=app, host=None, port=None)
preview = get_preview(app)

# %%
c = Div(P('hi'), style='color:red')
print(c)
# Out:
# <div style="color:red"><p>hi</p></div>

# %%
preview(c)
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_7knpwb3-S0qJYmDJyV1M2A&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;&lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div style=&quot;color:red&quot;&gt;
#        &lt;p&gt;hi&lt;/p&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
type(c)
# Out:
# fastcore.xml.FT

# %%
c.__dict__
# Out:
# {'tag': 'div',
#  'children': (p(('hi',),{}),),
#  'attrs': {'style': 'color:red'},
#  'void_': False,
#  'listeners_': []}

# %%
jt = """<div style="color:red"><p>hi</p></div>"""

# %%
template = jinja2.Template(jt)

# %%
template.render()
# Out:
# '<div style="color:red"><p>hi</p></div>'

# %%
preview(template.render())
# Out:
# <iframe src="<div style="color:red"><p>hi</p></div>" style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
type(template.render())
# Out:
# str

# %% [markdown]
# I need to create the same fastcore.xml.FT element using the ft function and bs4

# %%
#| export
from bs4 import BeautifulSoup

def parse_html_to_ft(html_str:str):
    """ Parse html to fastcore.xml"""
    soup = BeautifulSoup(html_str, 'html.parser')
    
    def convert_elem(elem):
        if isinstance(elem, str):
            return elem
        
        tag = elem.name
        children = [convert_elem(child) for child in elem.children]
        attrs = dict(elem.attrs)
        
        return ft(tag, *children, **attrs)
    
    return convert_elem(soup.find())

# %%
ft_template = parse_html_to_ft(template.render())
ft_template
# Out:
# div((p(('hi',),{}),),{'style': 'color:red'})

# %%
preview(ft_template)
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_Qv6IrTkbT5G3NoLFd-CFWg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;&lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div style=&quot;color:red&quot;&gt;
#        &lt;p&gt;hi&lt;/p&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
type(ft_template)
# Out:
# fastcore.xml.FT

# %%
ft_template.__dict__
# Out:
# {'tag': 'div',
#  'children': (p(('hi',),{}),),
#  'attrs': {'style': 'color:red'},
#  'void_': False,
#  'listeners_': []}

# %% [markdown]
# Now I can patch the jinja2.Template to have a module for fasthtml

# %%
#| export
@patch
def ft_render(self:jinja2.Template, *args, **kargs):
    "parse html to fastcore.xml.ft and render"
    return parse_html_to_ft(self.render(*args, **kargs))

# %% [markdown]
# I am checking with my previous example also.

# %%
preview(template.ft_render())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_1S-oI4OqRpaDduJtvvLjBw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;&lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div style=&quot;color:red&quot;&gt;
#        &lt;p&gt;hi&lt;/p&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
jinja_template = """<div> {{ name }} </div>
"""
jinja_template
# Out:
# '<div> {{ name }} </div>\n'

# %%
template = jinja2.Template(jinja_template)
template
# Out:
# <Template memory:7d7730a2ef60>

# %%
preview(template.render(name="Yann"))
# Out:
# <iframe src="<div> Yann </div>" style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
preview(template.ft_render(name="Yann"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_DmGunM4xQNGl-fpZswUHew&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;&lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div&gt; Yann &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ## Reproducing (testing?)

# %% [markdown]
# ### Writing SolveIt in SolveIt with Jinja

# %% [markdown]
# I will test some the first steps of lesson 4

# %% [markdown]
# #### Interactivity

# %%
from fastcore.utils import *
from fasthtml.common import *
from fasthtml.jupyter import *
import fasthtml.components as fc
import httpx

# %%
daisy_hdrs = (
    Link(href='https://cdn.jsdelivr.net/npm/daisyui@5', rel='stylesheet', type='text/css'),
    Script(src='https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4'),
    Link(href='https://cdn.jsdelivr.net/npm/daisyui@5/themes.css', rel='stylesheet', type='text/css')
)

# %%
app = FastHTML(hdrs=daisy_hdrs)
rt = app.route

# %%
srv = JupyUvi(app=app)

# %%
def get_preview(app):
    return partial(HTMX, app=app, host=None, port=None)
preview = get_preview(app)

# %%
@rt
def proc_btn(): return f'hi'

@rt
def testbtn():
    return Div(
        Button('click me', hx_post=proc_btn, id='btn', hx_target='#test', cls='btn'),
        Div(id='test')
    )

# %%
preview(testbtn())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_liTxrTo1S6S80wqzmiBzBg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div&gt;
# &lt;button hx-post=&quot;/proc_btn&quot; hx-target=&quot;#test&quot; id=&quot;btn&quot; class=&quot;btn&quot; name=&quot;btn&quot;&gt;click me&lt;/button&gt;       &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# Tip: There is https://h2f.answer.ai/ to convert html to fasthtml. To convert fasthml to html just run the code and copy. It will not work for everything but that's a good start.

# %%
Div(
        Button('click me', hx_post=proc_btn, id='btn', hx_target='#test', cls='btn'),
        Div(id='test')
    )
# Out:
# div((button(('click me',),{'hx-post': <fasthtml.core._mk_locfunc.<locals>._lf object>, 'hx-target': '#test', 'id': 'btn', 'class': 'btn', 'name': 'btn'}), div((),{'id': 'test'})),{})

# %%
testbtn_template = jinja2.Template("""<div>
<button hx-post="/proc_btn" hx-target="#test" id="btn" class="btn" name="btn">click me</button>  <div id="test"></div>
</div>
""")
testbtn_template
# Out:
# <Template memory:7d77303e4f80>

# %%
@rt
def testbtn_jinja():
    return testbtn_template.ft_render()

# %%
preview(testbtn_jinja())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_RtLA0U8GSBqLHqMLtq2yYw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div&gt;
#
# &lt;button hx-post=&quot;/proc_btn&quot; hx-target=&quot;#test&quot; id=&quot;btn&quot; class=&quot;btn&quot; name=&quot;btn&quot;&gt;click me&lt;/button&gt;        &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
#
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# #### Getting data in a route

# %%
@rt
def getinp(): return Input(type='text', placeholder='Type here')

# %%
preview(getinp)
# Out:
# <iframe src="/getinp" style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
getinp_template = jinja2.Template("<input type='text' placeholder='Type here'>")

# %%
@rt
def getinp_jinja():
    return getinp_template.ft_render()

# %%
preview(getinp_jinja())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_npvSJ9L5TtmiFFxynXHOCA&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;input type=&quot;text&quot; placeholder=&quot;Type here&quot;&gt;&lt;/input&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
def mk_comp(name, compcls):
    comp = getattr(fc, name)
    def wrapper(*args, cls='', **kwargs): return comp(*args, cls=f'{compcls} {cls}', **kwargs)
    globals()[name] = wrapper


mk_comp('Button', 'btn')
mk_comp('Input', 'input')

# %%
@rt
def proc_inp(inp:str): return f'hi {inp}'

@rt
def testinp():
    return Form(hx_post=proc_inp, hx_target='#test')(
        Input(type='text', placeholder='Type here', id='inp'),
        Button('say hi', type='submit'),
        Div(id='test')
    )

# %%
preview(testinp())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_0UBlWPWCTRW552l6-E7sFg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
# &lt;form enctype=&quot;multipart/form-data&quot; hx-post=&quot;/proc_inp&quot; hx-target=&quot;#test&quot;&gt;       &lt;input type=&quot;text&quot; placeholder=&quot;Type here&quot; id=&quot;inp&quot; class=&quot;input &quot; name=&quot;inp&quot;&gt;
# &lt;button type=&quot;submit&quot; class=&quot;btn &quot;&gt;say hi&lt;/button&gt;       &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
# &lt;/form&gt;   &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
form_jinja = jinja2.Template('''<form enctype="multipart/form-data" hx-post="/proc_inp" hx-target="#test">  <input type="text" placeholder="Type here" id="inp" class="input " name="inp">
<button type="submit" class="btn ">say hi</button>  <div id="test"></div>
</form>''')

# %%
@rt
def testinp_jinja():
    return form_jinja.ft_render()

# %%
preview(testinp_jinja())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_kAC_qTL3Q7OxjQM1SmJeBQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
# &lt;form enctype=&quot;multipart/form-data&quot; hx-post=&quot;/proc_inp&quot; hx-target=&quot;#test&quot;&gt;        &lt;input type=&quot;text&quot; placeholder=&quot;Type here&quot; id=&quot;inp&quot; class=&quot;input&quot; name=&quot;inp&quot;&gt;&lt;/input&gt;
#
# &lt;button type=&quot;submit&quot; class=&quot;btn&quot;&gt;say hi&lt;/button&gt;        &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
#
# &lt;/form&gt;   &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
def nameinp(oob=False):
    kw = dict(hx_swap_oob='true') if oob else {}
    return Input(type='text', placeholder='Type here', id='inp', **kw)

@rt
def proc_inp(inp:str): 
    return P(f'hi {inp}'), nameinp(True)

@rt
def testinp():
    return Form(hx_post=proc_inp, hx_target='#test', hx_swap='afterbegin')(
        nameinp(),
        Button('say hi', type='submit'),
        Div(id='test')
    )

# %%
preview(testinp())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_5GrCC4AqRrizQ9ZT8HHzsA&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
# &lt;form enctype=&quot;multipart/form-data&quot; hx-post=&quot;/proc_inp&quot; hx-swap=&quot;afterbegin&quot; hx-target=&quot;#test&quot;&gt;       &lt;input type=&quot;text&quot; placeholder=&quot;Type here&quot; id=&quot;inp&quot; class=&quot;input &quot; name=&quot;inp&quot;&gt;
# &lt;button type=&quot;submit&quot; class=&quot;btn &quot;&gt;say hi&lt;/button&gt;       &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
# &lt;/form&gt;   &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
def nameinp_jinja(oob=False):
    kw = dict(hx_swap_oob='true') if oob else {}
    return jinja2.Template('''
    <input type="text" placeholder="Type here" id="inp" class="input" name="inp" {% for key, value in kw.items() %}{{key}}="{{value}}"{% endfor %}>
''').ft_render(kw=kw)

@rt
def proc_inp_jinja(inp:str): 
    return jinja2.Template("<p> hi {{inp}}").ft_render(inp = inp), nameinp_jinja(True)

@rt
def testinp_jinja():
    return jinja2.Template('''<form enctype="multipart/form-data" hx-post="/proc_inp_jinja" hx-target="#test", hx_swap="afterbegin">  <input type="text" placeholder="Type here" id="inp" class="input " name="inp">
<button type="submit" class="btn ">say hi</button>  <div id="test"></div>
</form>''').ft_render()

# %%
preview(testinp_jinja())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_FW4xMCXuR6a257WZ_xjmug&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
# &lt;form enctype=&quot;multipart/form-data&quot; hx-post=&quot;/proc_inp_jinja&quot; hx-target=&quot;#test&quot; hx-swap=&quot;afterbegin&quot;&gt;        &lt;input type=&quot;text&quot; placeholder=&quot;Type here&quot; id=&quot;inp&quot; class=&quot;input&quot; name=&quot;inp&quot;&gt;&lt;/input&gt;
#
# &lt;button type=&quot;submit&quot; class=&quot;btn&quot;&gt;say hi&lt;/button&gt;        &lt;div id=&quot;test&quot;&gt;&lt;/div&gt;
#
# &lt;/form&gt;   &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### Jinja style

# %% [markdown]
# I will now try how I use Jinja with FastHTML, reading a file and checking inheritance.

# %% [markdown]
# #### From a file

# %%
jinja_template = """<div> {{ name }} </div>
"""
jinja_template
# Out:
# '<div> {{ name }} </div>\n'

# %%
# %mkdir templates

# %%
with open("templates/example.html", "w") as f:
    f.write(jinja_template)

# %%
# %ls templates/
# Out:
# example.html

# %% [markdown]
# I need to load the files from the environment

# %%
env = jinja2.Environment(loader=jinja2.FileSystemLoader('templates'))

# %%
template_from_file = env.get_template('example.html')
template_from_file
# Out:
# <Template 'example.html'>

# %%
@rt
def example_from_file(name):
    return template_from_file.ft_render(name=name)

# %%
preview(example_from_file(name="Yann"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_DlkmhjoISIOj_zF-zN7iUw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/daisyui@5/themes.css&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div&gt; Yann &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# #### Inheritance

# %% [markdown]
# To correctly load the jinja templates, they should be in the environment, so jinja knows what template exits.
#
# In addition to load by folder, I am adding a DictLoader.

# %%
parent = """<!DOCTYPE html>
<html lang="en">
<head>
    {% block head %}
    <link rel="stylesheet" href="style.css" />
    <title>{% block title %}{% endblock %} - My Webpage</title>
    {% endblock %}
</head>
<body>
    <div id="content">{% block content %}{% endblock %}</div>
    <div id="footer">
        {% block footer %}
        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.
        {% endblock %}
    </div>
</body>
</html>
"""

# %%
child = """{% extends "parent.html" %}
{% block title %}Index{% endblock %}
{% block head %}
    {{ super() }}
    <style type="text/css">
        .important { color: #336699; }
    </style>
{% endblock %}
{% block content %}
    <h1>Index</h1>
    <p class="important">
      Welcome to my awesome homepage.
    </p>
{% endblock %}
"""

# %%
templates_dict={}

env = jinja2.Environment(loader=jinja2.ChoiceLoader([
    jinja2.DictLoader(templates_dict),
    jinja2.FileSystemLoader('templates')
]))

# %%
templates_dict["parent.html"]=parent
templates_dict
# Out:
# {'parent.html': '<!DOCTYPE html>\n<html lang="en">\n<head>\n    {% block head %}\n    <link rel="stylesheet" href="style.css" />\n    <title>{% block title %}{% endblock %} - My Webpage</title>\n    {% endblock %}\n</head>\n<body>\n    <div id="content">{% block content %}{% endblock %}</div>\n    <div id="footer">\n        {% block footer %}\n        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.\n        {% endblock %}\n    </div>\n</body>\n</html>\n'}

# %%
parent_tp = env.get_template('parent.html')
parent_tp.ft_render()
# Out:
# html(('\n', head(('\n', link((),{'rel': 'stylesheet', 'href': 'style.css'}), '\n', title((' - My Webpage',),{}), '\n'),{}), '\n', body(('\n', div((),{'id': 'content'}), '\n', div(('\n        \n        © Copyright 2008 by ', a(('you',),{'href': 'http://domain.invalid/'}), '.\n        \n    '),{'id': 'footer'}), '\n'),{}), '\n'),{'lang': 'en'})

# %%
preview(parent_tp.ft_render())
# Out:
# <iframe srcdoc=" &lt;html lang=&quot;en&quot;&gt;
#
#    &lt;head&gt;
#
#      &lt;link rel=&quot;stylesheet&quot; href=&quot;style.css&quot;&gt;&lt;/link&gt;
#
#      &lt;title&gt; - My Webpage&lt;/title&gt;
#
#    &lt;/head&gt;
#
#    &lt;body&gt;
#
#      &lt;div id=&quot;content&quot;&gt;&lt;/div&gt;
#
#      &lt;div id=&quot;footer&quot;&gt;
#
#
#         © Copyright 2008 by &lt;a href=&quot;http://domain.invalid/&quot;&gt;you&lt;/a&gt;.
#
#          &lt;/div&gt;
#
#    &lt;/body&gt;
#
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
templates_dict['child.html'] = child

# %%
child_tp = env.get_template('child.html')
child_tp.ft_render()
# Out:
# html(('\n', head(('\n', link((),{'rel': 'stylesheet', 'href': 'style.css'}), '\n', title(('Index - My Webpage',),{}), '\n', style(('\n        .important { color: #336699; }\n    ',),{'type': 'text/css'}), '\n'),{}), '\n', body(('\n', div(('\n', h1(('Index',),{}), '\n', p(('\n      Welcome to my awesome homepage.\n    ',),{'class': 'important'}), '\n'),{'id': 'content'}), '\n', div(('\n        \n        © Copyright 2008 by ', a(('you',),{'href': 'http://domain.invalid/'}), '.\n        \n    '),{'id': 'footer'}), '\n'),{}), '\n'),{'lang': 'en'})

# %%
@rt
def child():
    return child_tp.ft_render()

# %%
preview(child())
# Out:
# <iframe srcdoc=" &lt;html lang=&quot;en&quot;&gt;
#
#    &lt;head&gt;
#
#      &lt;link rel=&quot;stylesheet&quot; href=&quot;style.css&quot;&gt;&lt;/link&gt;
#
#      &lt;title&gt;Index - My Webpage&lt;/title&gt;
#
#      &lt;style type=&quot;text/css&quot;&gt;
#         .important { color: #336699; }
#     &lt;/style&gt;
#
#    &lt;/head&gt;
#
#    &lt;body&gt;
#
#      &lt;div id=&quot;content&quot;&gt;
#
#        &lt;h1&gt;Index&lt;/h1&gt;
#
#        &lt;p class=&quot;important&quot;&gt;
#       Welcome to my awesome homepage.
#     &lt;/p&gt;
#
#      &lt;/div&gt;
#
#      &lt;div id=&quot;footer&quot;&gt;
#
#
#         © Copyright 2008 by &lt;a href=&quot;http://domain.invalid/&quot;&gt;you&lt;/a&gt;.
#
#          &lt;/div&gt;
#
#    &lt;/body&gt;
#
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# #### Correctly importing templates from code for inheritance

# %%
#| export
templates_dict={}

env = jinja2.Environment(loader=jinja2.ChoiceLoader([
    jinja2.DictLoader(templates_dict),
    jinja2.FileSystemLoader('templates')
]))

# %%
#| export

def add_template_from_code(
    templates_dict:dict[str], 
    code:str, 
    filename:str) :
    "Correct way to add a Jinja template to get inheritance"
    
    templates_dict[filename] = code
    return env.get_template(filename)

# %% [markdown]
# ## Exporting templates like nbdev

# %% [markdown]
# All of this would not be worth if I could not export templates as I can export with nbdev.
#
# My current hack is to have a tag `#| exportjinja namefile.html` and use `find_msgs` from `dialoghelper`  to find those

# %%
#| exportjinja parent.html
parent = """<!DOCTYPE html>
<html lang="en">
<head>
    {% block head %}
    <link rel="stylesheet" href="style.css" />
    <title>{% block title %}{% endblock %} - My Webpage</title>
    {% endblock %}
</head>
<body>
    <div id="content">{% block content %}{% endblock %}</div>
    <div id="footer">
        {% block footer %}
        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.
        {% endblock %}
    </div>
</body>
</html>
"""

# %%
#| export
from dialoghelper import find_msgs

# %%
x = find_msgs(re_pattern="#\\| exportjinja", msg_type="code")[0]["content"]
x
# Out:
# '#| exportjinja parent.html\nparent = """<!DOCTYPE html>\n<html lang="en">\n<head>\n    {% block head %}\n    <link rel="stylesheet" href="style.css" />\n    <title>{% block title %}{% endblock %} - My Webpage</title>\n    {% endblock %}\n</head>\n<body>\n    <div id="content">{% block content %}{% endblock %}</div>\n    <div id="footer">\n        {% block footer %}\n        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.\n        {% endblock %}\n    </div>\n</body>\n</html>\n"""'

# %%
first_line = x.split('\n')[0]
file_name = first_line.split("exportjinja")[-1].strip()
file_name
# Out:
# 'parent.html'

# %%
content = x.split('"""')[1]
content
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    {% block head %}\n    <link rel="stylesheet" href="style.css" />\n    <title>{% block title %}{% endblock %} - My Webpage</title>\n    {% endblock %}\n</head>\n<body>\n    <div id="content">{% block content %}{% endblock %}</div>\n    <div id="footer">\n        {% block footer %}\n        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.\n        {% endblock %}\n    </div>\n</body>\n</html>\n'

# %%
with open(f"templates/{file_name}", "w") as f:
        f.write(content)

# %%
# %ls templates
# Out:
# child.html  example.html  parent.html

# %%
#| export
def export_jinja_template(cell:str, templates_folder:str ="templates"):
    "Export single cell"
    first_line = cell.split('\n')[0]
    file_name = first_line.split("exportjinja")[-1].strip()
    
    if len(cell.split('"""')) == 3:
        content = cell.split('"""')[1]

    elif len(cell.split("'''")) == 3:
        content = cell.split("'''")[1]

    else:
        print("cannot find")
        return None
    
    with open(f"{templates_folder}/{file_name}", "w") as f:
        f.write(content)

# %%
# %rm templates/parent.html

# %%
# %ls templates
# Out:
# child.html  example.html

# %%
export_jinja_template(x)

# %%
# %ls templates
# Out:
# child.html  example.html  parent.html

# %%
# !cat templates/parent.html
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     {% block head %}
#     <link rel="stylesheet" href="style.css" />
#     <title>{% block title %}{% endblock %} - My Webpage</title>
#     {% endblock %}
# </head>
# <body>
#     <div id="content">{% block content %}{% endblock %}</div>
#     <div id="footer">
#         {% block footer %}
#         &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.
#         {% endblock %}
#     </div>
# </body>
# </html>

# %%
x = find_msgs(re_pattern="#\\| exportjinja", msg_type="code")[0]["content"]
x
# Out:
# '#| exportjinja parent.html\nparent = """<!DOCTYPE html>\n<html lang="en">\n<head>\n    {% block head %}\n    <link rel="stylesheet" href="style.css" />\n    <title>{% block title %}{% endblock %} - My Webpage</title>\n    {% endblock %}\n</head>\n<body>\n    <div id="content">{% block content %}{% endblock %}</div>\n    <div id="footer">\n        {% block footer %}\n        &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.\n        {% endblock %}\n    </div>\n</body>\n</html>\n"""'

# %%
#| export
def export_jinja_templates():
    " Export all jinja template cells"
    cells_to_export = find_msgs(re_pattern="#\\| exportjinja", msg_type="code")
    [export_jinja_template(cell["content"]) for cell in cells_to_export]

# %%
#| exportjinja child.html
child = """{% extends "parent.html" %}
{% block title %}Index{% endblock %}
{% block head %}
    {{ super() }}
    <style type="text/css">
        .important { color: #336699; }
    </style>
{% endblock %}
{% block content %}
    <h1>Index</h1>
    <p class="important">
      Welcome to my awesome homepage.
    </p>
{% endblock %}
"""

# %%
# %rm templates/parent.html

# %%
# %ls templates
# Out:
# child.html  example.html

# %%
export_jinja_templates()

# %%
# %ls templates
# Out:
# child.html  example.html  parent.html

# %%
# !cat templates/parent.html
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     {% block head %}
#     <link rel="stylesheet" href="style.css" />
#     <title>{% block title %}{% endblock %} - My Webpage</title>
#     {% endblock %}
# </head>
# <body>
#     <div id="content">{% block content %}{% endblock %}</div>
#     <div id="footer">
#         {% block footer %}
#         &copy; Copyright 2008 by <a href="http://domain.invalid/">you</a>.
#         {% endblock %}
#     </div>
# </body>
# </html>

# %%
# !cat templates/child.html
# Out:
# {% extends "parent.html" %}
# {% block title %}Index{% endblock %}
# {% block head %}
#     {{ super() }}
#     <style type="text/css">
#         .important { color: #336699; }
#     </style>
# {% endblock %}
# {% block content %}
#     <h1>Index</h1>
#     <p class="important">
#       Welcome to my awesome homepage.
#     </p>
# {% endblock %}

# %%
#| hide
import nbdev; nbdev.nbdev_export()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 #| hide
# ----> 2 import nbdev; nbdev.nbdev_export()
#
# File /usr/local/lib/python3.12/site-packages/fastcore/script.py:116, in call_parse.<locals>._f(*args, **kwargs)
#     113 @wraps(func)
#     114 def _f(*args, **kwargs):
#     115     mod = inspect.getmodule(inspect.currentframe().f_back)
# --> 116     if not mod: return func(*args, **kwargs)
#     117     if not SCRIPT_INFO.func and mod.__name__=="__main__": SCRIPT_INFO.func = func.__name__
#     118     if len(sys.argv)>1 and sys.argv[1]=='': sys.argv.pop(1)
#
# File /usr/local/lib/python3.12/site-packages/nbdev/doclinks.py:158, in nbdev_export(path, procs, **kwargs)
#     156     procs = [getattr(nbdev.export, p) for p in L(procs)]
#     157 files = nbglob(path=path, as_path=True, **kwargs).sorted('name')
# --> 158 for f in files: nb_export(f, procs=procs)
#     159 add_init(get_config().lib_path)
#     160 _build_modidx()
#
# File /usr/local/lib/python3.12/site-packages/nbdev/export.py:81, in nb_export(nbname, lib_path, procs, name, mod_maker, debug, solo_nb)
#      79 if lib_path is None: lib_path = get_config().lib_path if is_nbdev() else '.'
#      80 exp = ExportModuleProc()
# ---> 81 nb = NBProcessor(nbname, [exp]+L(procs), debug=debug)
#      82 nb.process()
#      83 for mod,cells in exp.modules.items():
#
# File /usr/local/lib/python3.12/site-packages/nbdev/process.py:95, in NBProcessor.__init__(self, path, procs, nb, debug, rm_directives, process)
#      94 def __init__(self, path=None, procs=None, nb=None, debug=False, rm_directives=True, process=False):
# ---> 95     self.nb = read_nb(path) if nb is None else nb
#      96     self.lang = nb_lang(self.nb)
#      97     for cell in self.nb.cells: cell.directives_ = extract_directives(cell, remove=rm_directives, lang=self.lang)
#
# File /usr/local/lib/python3.12/site-packages/execnb/nbio.py:59, in read_nb(path)
#      57 def read_nb(path):
#      58     "Return notebook at `path`"
# ---> 59     res = dict2nb(_read_json(path, encoding='utf-8'))
#      60     res['path_'] = str(path)
#      61     return res
#
# File /usr/local/lib/python3.12/site-packages/execnb/nbio.py:18, in _read_json(self, encoding, errors)
#      17 def _read_json(self, encoding=None, errors=None):
# ---> 18     return loads(Path(self).read_text(encoding=encoding, errors=errors))
#
# File /usr/local/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/local/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     333 def decode(self, s, _w=WHITESPACE.match):
#     334     """Return the Python representation of ``s`` (a ``str`` instance
#     335     containing a JSON document).
#     336
#     337     """
# --> 338     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339     end = _w(s, end).end()
#     340     if end != len(s):
#
# File /usr/local/lib/python3.12/json/decoder.py:356, in JSONDecoder.raw_decode(self, s, idx)
#     354     obj, end = self.scan_once(s, idx)
#     355 except StopIteration as err:
# --> 356     raise JSONDecodeError("Expecting value", s, err.value) from None
#     357 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
